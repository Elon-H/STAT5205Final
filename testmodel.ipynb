# %%
# !python segment/predict.py \
--weights /home/yh3719/yolov5/runs/train-seg/exp8/weights/best.pt \
--source /home/yh3719/yolov5/9.mov \
--img 720 \
--conf 0.25 \
--device 0
# Out:
# segment/predict: weights=['/home/yh3719/yolov5/runs/train-seg/exp8/weights/best.pt'], source=/home/yh3719/yolov5/9.mov, data=data/coco128.yaml, imgsz=[720, 720], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.10.15 torch-2.7.0+cu126 CUDA:0 (NVIDIA L4, 22478MiB)
#
# Fusing layers...
# YOLOv5n-seg summary: 165 layers, 1882456 parameters, 0 gradients, 6.7 GFLOPs
# WARNING ⚠️ --img-size [720, 720] must be multiple of max stride 32, updating to [736, 736]
# video 1/1 (1/957) /home/yh3719/yolov5/9.mov: 416x736 1 walkable_area, 2 obstacles, 1 human, 53.4ms
# ...

# %%
# !python3.8 segment/predict.py \
--weights best.engine \
--data dataset/data.yaml\
--source 9.mov \
--img 640 \
--conf 0.25 \
--device 0
# Out:
# segment/predict: weights=['best.engine'], source=9.mov, data=dataset/data.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 73d6d58 Python-3.8.0 torch-1.11.0a0+gitbc2c6ed CUDA:0 (NVIDIA Tegra X1, 1980MiB)
#
# Loading best.engine for TensorRT inference...
# [05/13/2025-15:48:11] [TRT] [I] [MemUsageChange] Init CUDA: CPU +230, GPU +0, now: CPU 325, GPU 1928 (MiB)
# [05/13/2025-15:48:11] [TRT] [I] Loaded engine size: 7 MiB
# [05/13/2025-15:48:14] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU -10, now: CPU 497, GPU 1940 (MiB)
# ...

# %%
# !python3.8 segment/val.py \
--weights best.engine \
--data dataset/data.yaml\
--img 640 \
--conf 0.25 \
--batch-size 1 \
--device 0
# Out:
# segment/val: data=dataset/data.yaml, weights=['best.engine'], batch_size=1, imgsz=640, conf_thres=0.25, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val-seg, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.25 > 0.001 produces invalid results
# YOLOv5 🚀 73d6d58 Python-3.8.0 torch-1.11.0a0+gitbc2c6ed CUDA:0 (NVIDIA Tegra X1, 1980MiB)
#
# Loading best.engine for TensorRT inference...
# [05/13/2025-16:17:20] [TRT] [I] [MemUsageChange] Init CUDA: CPU +229, GPU +0, now: CPU 318, GPU 1946 (MiB)
# [05/13/2025-16:17:20] [TRT] [I] Loaded engine size: 7 MiB
# [05/13/2025-16:17:23] [TRT] [I] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU +1, now: CPU 490, GPU 1945 (MiB)
# [05/13/2025-16:17:27] [TRT] [I] [MemUsageChange] Init cuDNN: CPU +241, GPU +0, now: CPU 731, GPU 1945 (MiB)
# ...
